# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrecassimiro/VD/blob/main/terms_in_enterprise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image
import numpy as np

# Dados de exemplo
termos = ['Python', 'Data Science', 'Machine Learning', 'Big Data', 'IA', 'Nuvem', 'Programação']

# Carregando a imagem e convertendo para array de bytes
# mascara = np.array(Image.open("/content/balao.png").convert('L'), dtype=np.uint8)
mascara = np.array(Image.open("/content/enterprise-ncc-1701.jpg").convert('L'), dtype=np.uint8)



# Configuração do WordCloud
wordcloud = WordCloud(background_color='white', contour_color='black', contour_width=2, mask=mascara)

# Gere a nuvem de termos
wordcloud.generate(' '.join(termos))

# Plote a nuvem de termos
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
